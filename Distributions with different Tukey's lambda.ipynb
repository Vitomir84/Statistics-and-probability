# %% [markdown]
# ## Small experimentation with Tukey's Lambda

# %% [markdown]
# The Tukey Lambda PPCC plot, with shape parameter λ, is particularly useful for symmetric distributions. It indicates whether a distribution is short or long tailed and it can further indicate several common distributions. Specifically,
#
# λ = -1: distribution is approximately Cauchy
#
# λ = 0: distribution is exactly logistic
#
# λ = 0.14: distribution is approximately normal
#
# λ = 0.5: distribution is U-shaped
#
# λ = 1: distribution is exactly uniform
#
# https://docs.scipy.org/doc/scipy/reference/tutorial/stats/continuous_tukeylambda.html

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import tukeylambda

# %% [markdown]
# ### Cauchy distribution

# %%
np.random.seed(1234567)
lambda_ = -1
x = stats.tukeylambda.rvs(lambda_, loc=2, scale=0.5, size=10000) + 1e4

# %%
fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

res = stats.probplot(x, plot=ax1)
res = stats.boxcox_normplot(x, -5, 5, plot=ax2)
res = stats.ppcc_plot(x, -5, 5, plot=ax3)
ax3.vlines(-0.7, 0, 1, colors='r', label='Expected shape value')
plt.show()

# %%
mean, var, skew, kurt = tukeylambda.stats(lambda_, moments='mvsk')
z = np.linspace(tukeylambda.ppf(0.01, lambda_), tukeylambda.ppf(0.99, lambda_), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(z, tukeylambda.pdf(z, lambda_),'r-', lw=5, alpha=0.6, label='tukeylambda pdf')
ax.set_title('Cauchy distribution, lambda = -1');

# %% [markdown]
# ### Normal Gaussian distribution

# %%
np.random.seed(1234567)
# we plot normal distribution 
lambda_ = 0.14
y = stats.tukeylambda.rvs(lambda_, loc=2, scale=0.5, size=10000) + 1e4

# %%
fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)
res = stats.probplot(y, plot=ax1)
res = stats.boxcox_normplot(x, -5, 5, plot=ax2)
res = stats.ppcc_plot(y, -5, 5, plot=ax3)
ax3.vlines(0, 2, 0.5, colors='r', label='Expected shape value')
plt.show()

# %%
mean, var, skew, kurt = tukeylambda.stats(lambda_, moments='mvsk')
x = np.linspace(tukeylambda.ppf(0.01, lambda_), tukeylambda.ppf(0.99, lambda_), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, tukeylambda.pdf(x, lambda_),'r-', lw=5, alpha=0.6, label='tukeylambda pdf')
ax.set_title('Normal distribution, lambda = 0.14');

# %% [markdown]
# ### Uniform distribution

# %%
lambda_ = 1
x = stats.tukeylambda.rvs(lambda_, loc=2, scale=0.5, size=10000) + 1e4
fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

res = stats.probplot(x, plot=ax1)
res = stats.boxcox_normplot(x, -5, 5, plot=ax2)
res = stats.ppcc_plot(x, -5, 5, plot=ax3)
ax3.vlines(-0.7, 0, 1, colors='r', label='Expected shape value')
plt.show()

# %%
#Uniformna distribucija
mean, var, skew, kurt = tukeylambda.stats(lambda_, moments='mvsk')
y = np.linspace(tukeylambda.ppf(0.01, lambda_), tukeylambda.ppf(0.99, lambda_), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(y, tukeylambda.pdf(y, lambda_),'r-', lw=5, alpha=0.6, label='tukeylambda pdf')
ax.set_title('Uniform distribution, lambda = 1');

# %% [markdown]
# ### Logistic distribution

# %%
lambda_ = 0
x = stats.tukeylambda.rvs(lambda_, loc=2, scale=0.5, size=10000) + 1e4
fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

res = stats.probplot(x, plot=ax1)
res = stats.boxcox_normplot(x, -5, 5, plot=ax2)
res = stats.ppcc_plot(x, -5, 5, plot=ax3)
ax3.vlines(-0.7, 0, 1, colors='r', label='Expected shape value')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
mean, var, skew, kurt = tukeylambda.stats(lambda_, moments='mvsk')
z = np.linspace(tukeylambda.ppf(0.01, lambda_), tukeylambda.ppf(0.99, lambda_), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(z, tukeylambda.pdf(z, lambda_),'r-', lw=5, alpha=0.6, label='tukeylambda pdf')
ax.set_title('Logistic distribution, lambda = 0');

# %% [markdown]
# ### U - shaped

# %%
lambda_ = 0.5
x = stats.tukeylambda.rvs(lambda_, loc=2, scale=0.5, size=10000) + 1e4
fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

res = stats.probplot(x, plot=ax1)
res = stats.boxcox_normplot(x, -5, 5, plot=ax2)
res = stats.ppcc_plot(x, -5, 5, plot=ax3)
ax3.vlines(-0.7, 0, 1, colors='r', label='Expected shape value')
plt.show()

# %%
mean, var, skew, kurt = tukeylambda.stats(lambda_, moments='mvsk')
z = np.linspace(tukeylambda.ppf(0.01, lambda_), tukeylambda.ppf(0.99, lambda_), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(z, tukeylambda.pdf(z, lambda_),'r-', lw=5, alpha=0.6, label='tukeylambda pdf')
ax.set_title('Logistic distribution, lambda = 0.5');
